# %%
# %run ./LinearRegression.ipynb
# Out:
# Train R2 Score:  0.45555590764504417
# Test R2 Score:  0.4291782688312411
# Ortalama Test Hatası:  0.8674393552179401
# Ortalama Train Hatası:  1.0783029500384542
# Sabit Katsayı:  [0.87695764]
# Ağırlıklar:  [[0.10889371]]
# Toplam ücreti giriniz..4
# Tahmin [1.31253248]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.scatter(x_train,y_train,color = 'red')
plt.plot(x_train,linear_reg.predict(x_train),color="blue")

plt.title("Thruth or Bluff(Linear regression)")
plt.xlabel("Total Bill")
plt.ylabel("Tip")
#plt.show()
# Out:
# Text(0, 0.5, 'Tip')
